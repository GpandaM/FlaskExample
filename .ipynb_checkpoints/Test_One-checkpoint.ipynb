# %% [markdown]
# # Markdown
#
# This is in [Markdown].
#
# ##Sub Heading
#
# How *are* you **doing**?

# %%
jupyter notebook --port 9000
# Out:
#   File "<ipython-input-5-c363a0c3dd56>", line 1
#     jupyter notebook --port 9000
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np
np.arange?

# %%
# %timeit x = 10 + 20
# Out:
# 10000000 loops, best of 3: 13.4 ns per loop

# %%
# %timeit
print("Haathi mere Saathi")
# Out:
# Haathi mere Saathi

# %%
import time
# %timeit time.sleep(2)
# Out:
# 1 loop, best of 3: 2 s per loop

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is F45A-09F5
#
#  Directory of C:\Users\garima.misra\Desktop
#
# 12/10/2018  12:54 PM    <DIR>          .
# 12/10/2018  12:54 PM    <DIR>          ..
# 12/10/2018  12:05 PM    <DIR>          .ipynb_checkpoints
# 11/27/2018  04:36 PM            13,837 Copy of Montly Activity Format.xlsx
# 12/03/2018  02:53 PM           284,173 Copy of Nov-18 Report.xlsx
# 11/22/2018  09:19 AM               102 Global Data Privacy Statement.url
# 11/22/2018  09:19 AM             1,417 Microsoft Edge.lnk
# 12/04/2018  04:53 PM             1,507 PA tool.txt
# 12/06/2018  05:05 PM           411,457 page1.jpg
# 12/06/2018  05:05 PM           397,198 page2.jpg
# 12/06/2018  05:05 PM           418,865 page3.jpg
# 12/06/2018  05:05 PM           411,457 scanner_20181206_170014
# 12/06/2018  05:05 PM           397,198 scanner_20181206_170028
# 12/06/2018  04:20 PM           899,173 ShampaBCCLNoidaIDCardForm.pdf
# ...

# %%
pwd
# Out:
# u'C:\\Users\\garima.misra\\Desktop'

# %%
echo "Hello World"
# Out:
# "Hello World"

# %%
# %load_ext sql

# %%
# %sql sqlite:///pollution_test6.db
# Out:
# u'Connected: @pollution_test6.db'

# %%
# %%sql
# Select * from pollution_data LIMIT 10 OFFSET (Select Count(*) from pollution_data) -10;
# Out:
#    sqlite://
#  * sqlite:///pollution_test6.db
# Done.
# [(353.0, 122.0, 13.0, 55.0, 353.0, 351.0, u'PM10', 353.0, None, u'2018-12-06 11:00:00', 6, u'Thursday', 11, 12, u'Sector - 62, Noida, UP - IMD', 2018),
#  (367.0, 27.0, 160.0, 170.0, 270.0, 367.0, u'PM25', 367.0, 34.0, u'2018-12-06 11:00:00', 6, u'Thursday', 11, 12, u'Ardhali Bazar, Varanasi - UPPCB', 2018),
#  (221.0, 51.0, 62.0, 18.0, 153.0, 221.0, u'PM25', 221.0, 13.0, u'2018-12-06 11:00:00', 6, u'Thursday', 11, 12, u'Asansol Court Area, Asansol - WBPCB', 2018),
#  (165.0, 70.0, None, None, 165.0, None, u'PM10', 165.0, 17.0, u'2018-12-06 11:00:00', 6, u'Thursday', 11, 12, u'Sidhu Kanhu Indoor Stadium, Durgapur - WBPCB', 2018),
#  (178.0, 43.0, 46.0, 13.0, 178.0, None, u'PM10', 178.0, 14.0, u'2018-12-06 11:00:00', 6, u'Thursday', 11, 12, u'Haldia, Haldia - WBPCB', 2018),
#  (326.0, 63.0, 141.0, 17.0, 286.0, 326.0, u'PM25', 326.0, 85.0, u'2018-12-06 11:00:00', 6, u'Thursday', 11, 12, u'Ghusuri, Howrah - WBPCB', 2018),
# ...

# %%
# %load_ext version_information
# %version_information requests, numpy, pandas, matplotlib, seaborn, sklearn, bs4, sqlite3, sys, os, datetime
# Out:
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# Software versions
# Python 2.7.15 64bit [MSC v.1500 64 bit (AMD64)]
# IPython 5.8.0
# OS Windows 10 10.0.17134
# requests 2.19.1
# numpy 1.15.1
# pandas 0.23.4
# matplotlib 2.2.3
# seaborn 0.9.0
# sklearn 0.19.2
# bs4 4.6.3
# sqlite3 The 'sqlite3' distribution was not found and is required by the application
# sys The 'sys' distribution was not found and is required by the application
# os The 'os' distribution was not found and is required by the application
# datetime The 'datetime' distribution was not found and is required by the application
# Mon Dec 10 14:17:37 2018 India Standard Time

# %%
from sklearn import datasets
boston = datasets.load_boston()

# %%
type(boston)
# Out:
# sklearn.utils.Bunch

# %%
from sklearn.utils import Bunch
Bunch?

# %%
for k in boston.items():
    print(k)
# Out:
# ('data', array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]))
# ('feature_names', array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='|S7'))
# ...

# %%
boston['data'].shape
# Out:
# (506L, 13L)

# %%
boston['feature_names']
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='|S7')

# %%
boston['target']
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
boston['target'].shape
# Out:
# (506L,)

# %%
boston["MEDV"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-3e2391c06ea0> in <module>()
# ----> 1 boston["MEDV"]
#
# KeyError: 'MEDV'

# %%
boston['MEDV']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-a1349e14bf54> in <module>()
# ----> 1 boston['MEDV']
#
# KeyError: 'MEDV'

# %%
boston
# Out:
# {'DESCR': "Boston House Prices dataset\n===========================\n\nNotes\n------\nData Set Characteristics:  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive\n    \n    :Median Value (attribute 14) is usually the target\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate p
# ...

# %%
boston['DESCR']
# Out:
# "Boston House Prices dataset\n===========================\n\nNotes\n------\nData Set Characteristics:  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive\n    \n    :Median Value (attribute 14) is usually the target\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000
# ...

# %%
boston['data']
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
import pandas as pd
df = pd.DataFrame(boston['data'], columns = boston['feature_names'])

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88

# %%
columns
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='|S7')

# %%
boston['DESCR']['MEDV']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-91f81123bcef> in <module>()
# ----> 1 boston['DESCR']['MEDV']
#
# TypeError: string indices must be integers, not str

# %%
df['MEDV'] = boston['target']

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
y = df['MEDV'].copy()
del df["MEDV"]
df = pd.concat((y, df), axis = 1)

# %%
df.head()
# Out:
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df.dtypes
# Out:
# MEDV       float64
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD        float64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# dtype: object

# %%
df.isnull()
# Out:
#       MEDV   CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False  False  False  False
# 6    False  False  False  False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# MEDV       0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %%
for col in ['ZN', 'NOX', 'RAD', 'PTRATIO', 'B']:
    del df[col]

# %%
df.head()
# Out:
#    MEDV     CRIM  INDUS  CHAS     RM   AGE     DIS    TAX  LSTAT
# 0  24.0  0.00632   2.31   0.0  6.575  65.2  4.0900  296.0   4.98
# 1  21.6  0.02731   7.07   0.0  6.421  78.9  4.9671  242.0   9.14
# 2  34.7  0.02729   7.07   0.0  7.185  61.1  4.9671  242.0   4.03
# 3  33.4  0.03237   2.18   0.0  6.998  45.8  6.0622  222.0   2.94
# 4  36.2  0.06905   2.18   0.0  7.147  54.2  6.0622  222.0   5.33

# %%
df.describe()
# Out:
#              MEDV        CRIM       INDUS        CHAS          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.532806    3.593761   11.136779    0.069170    6.284634   68.574901
# std      9.197104    8.596783    6.860353    0.253994    0.702617   28.148861
# min      5.000000    0.006320    0.460000    0.000000    3.561000    2.900000
# 25%     17.025000    0.082045    5.190000    0.000000    5.885500   45.025000
# 50%     21.200000    0.256510    9.690000    0.000000    6.208500   77.500000
# 75%     25.000000    3.647423   18.100000    0.000000    6.623500   94.075000
# max     50.000000   88.976200   27.740000    1.000000    8.780000  100.000000
#
#               DIS         TAX       LSTAT
# count  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   12.653063
# std      2.105710  168.537116    7.141062
# min      1.129600  187.000000    1.730000
# 25%      2.100175  279.000000    6.950000
# ...

# %%
cols = ['RM', 'AGE', 'TAX', 'LSTAT', 'MEDV']
df[cols].head()
# Out:
#       RM   AGE    TAX  LSTAT  MEDV
# 0  6.575  65.2  296.0   4.98  24.0
# 1  6.421  78.9  242.0   9.14  21.6
# 2  7.185  61.1  242.0   4.03  34.7
# 3  6.998  45.8  222.0   2.94  33.4
# 4  7.147  54.2  222.0   5.33  36.2

# %%
df[cols].corr()
# Out:
#              RM       AGE       TAX     LSTAT      MEDV
# RM     1.000000 -0.240265 -0.292048 -0.613808  0.695360
# AGE   -0.240265  1.000000  0.506456  0.602339 -0.376955
# TAX   -0.292048  0.506456  1.000000  0.543993 -0.468536
# LSTAT -0.613808  0.602339  0.543993  1.000000 -0.737663
# MEDV   0.695360 -0.376955 -0.468536 -0.737663  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ax = sns.heatmap(df[cols].corr(), cmap = sns.cubehelix_palette(20, light = 0.95, dark = 0.15))
ax.xaxis.tick_top()
plt.savefig('test_pic1.png', dpi=500, bbox_inches = 'tight')

# %%
sns.pairplot(df[cols])

# %%
sns.pairplot(df[cols], plot_kws={'alpha':0.8}, diag_kws={'bins':50}) #alpha for transparency

# %%
fig, ax = plt.subplots(1,2)
sns.regplot('RM', 'MEDV', df, ax = ax[0], scatter_kws={'alpha':0.4})
sns.regplot('LSTAT', 'MEDV', df, ax = ax[1], scatter_kws={'alpha':0.4})
